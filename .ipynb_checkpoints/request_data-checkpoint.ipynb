# %%
import requests
import quandl
import pandas as pd
import numpy as np
from datetime import timedelta
from bokeh.plotting import figure, output_file, show

# %%
quandl.ApiConfig.api_key = "DotxFs2bJksfE6SfssR4"
# pass which database and which ticker
ticker = input("Ticker symbol:")
data = quandl.get("WIKI/{}".format(ticker))[['Open','Close','Adj. Open','Adj. Close']]
today = pd.to_datetime('today')
last_mon = today-timedelta(days=30)
index = (np.where(data.index>last_mon)[0])
last_mon_data = data[index[0]:]
y = last_mon_data.index
x1 = last_mon_data[[feature1]]
x2 = last_mon_data[[feature2]]
x3 = last_mon_data[[feature3]]
x4 = last_mon_data[[feature4]]
# y = range(5)
# x1 = range(5)
p = figure(title="Stock Price Plot for Last Month", x_axis_label='Date', y_axis_label='Price')
#p.line(y, x1, legend='google', line_width=2)
p.line(y, x1, legend="{}".format(ticker), line_width=2)
p.line(y, x2, legend="{}".format(ticker), line_width=2)
p.line(y, x3, legend="{}".format(ticker), line_width=2)
p.line(y, x4, legend="{}".format(ticker), line_width=2)
# Out:
# Ticker symbol:GOOG
# GlyphRenderer(id='548473b5-6669-4601-83c4-9610ad2b590b', ...)

# %%
import requests

api_url = 'https://www.quandl.com/api/v1/datasets/WIKI/%s.json' % ticker
session = requests.Session()
session.mount('http://', requests.adapters.HTTPAdapter(max_retries=3))
raw_data = session.get(api_url)

# %%
txt = raw_data.json()
import pandas as pd
import numpy as np

# %%
col = txt[list(txt.keys())[13]]
data = txt['data']
data = pd.DataFrame(data=data, columns=col)[['Date','Close','Adj. Close','Open','Adj. Open']]
data
# Out:
#            Date   Close  Adj. Close     Open  Adj. Open
# 0    2017-09-11  929.08      929.08  934.250    934.250
# 1    2017-09-08  926.50      926.50  936.490    936.490
# 2    2017-09-07  935.95      935.95  931.730    931.730
# 3    2017-09-06  927.81      927.81  930.150    930.150
# 4    2017-09-05  928.45      928.45  933.080    933.080
# 5    2017-09-01  937.34      937.34  941.130    941.130
# 6    2017-08-31  939.33      939.33  931.760    931.760
# 7    2017-08-30  929.57      929.57  920.050    920.050
# 8    2017-08-29  921.29      921.29  905.100    905.100
# 9    2017-08-28  913.81      913.81  916.000    916.000
# 10   2017-08-25  915.89      915.89  923.490    923.490
# 11   2017-08-24  921.28      921.28  928.660    928.660
# 12   2017-08-23  927.00      927.00  921.930    921.930
# 13   2017-08-22  924.69      924.69  912.720    912.720
# 14   2017-08-21  906.66      906.66  910.000    910.000
# 15   2017-08-18  910.67      910.67  910.310    910.310
# 16   2017-08-17  910.98      910.98  925.780    925.780
# 17   2017-08-16  926.96      926.96  925.290    925.290
# 18   2017-08-15  922.22      922.22  924.230    924.230
# 19   2017-08-14  922.67      922.67  922.530    922.530
# 20   2017-08-11  914.39      914.39  907.970    907.970
# 21   2017-08-10  907.24      907.24  917.550    917.550
# 22   2017-08-09  922.90      922.90  920.610    920.610
# 23   2017-08-08  926.79      926.79  927.090    927.090
# 24   2017-08-07  929.36      929.36  929.060    929.060
# 25   2017-08-04  927.96      927.96  926.750    926.750
# 26   2017-08-03  923.65      923.65  930.340    930.340
# 27   2017-08-02  930.39      930.39  928.610    928.610
# 28   2017-08-01  930.83      930.83  932.380    932.380
# 29   2017-07-31  930.50      930.50  941.890    941.890
# ..          ...     ...         ...      ...        ...
# 842  2014-05-08  511.00      511.00  508.460    508.460
# 843  2014-05-07  509.96      509.96  515.790    515.790
# 844  2014-05-06  515.14      515.14  525.230    525.230
# 845  2014-05-05  527.81      527.81  524.820    524.820
# 846  2014-05-02  527.93      527.93  533.760    533.760
# 847  2014-05-01  531.35      531.35  527.110    527.110
# 848  2014-04-30  526.66      526.66  527.600    527.600
# 849  2014-04-29  527.70      527.70  516.900    516.900
# 850  2014-04-28  517.15      517.15  517.180    517.180
# 851  2014-04-25  516.18      516.18  522.510    522.510
# 852  2014-04-24  525.16      525.16  530.070    530.070
# 853  2014-04-23  526.94      526.94  533.790    533.790
# 854  2014-04-22  534.81      534.81  528.640    528.640
# 855  2014-04-21  528.62      528.62  536.100    536.100
# 856  2014-04-17  536.10      536.10  548.810    548.810
# 857  2014-04-16  556.54      556.54  543.000    543.000
# 858  2014-04-15  536.44      536.44  536.820    536.820
# 859  2014-04-14  532.52      532.52  538.250    538.250
# 860  2014-04-11  530.60      530.60  532.550    532.550
# 861  2014-04-10  540.95      540.95  565.000    565.000
# 862  2014-04-09  564.14      564.14  559.620    559.620
# 863  2014-04-08  554.90      554.90  542.600    542.600
# 864  2014-04-07  538.15      538.15  540.740    540.740
# 865  2014-04-04  543.14      543.14  574.650    574.650
# 866  2014-04-03  569.74      569.74  569.850    569.850
# 867  2014-04-02  567.00      567.00  565.106    565.106
# 868  2014-04-01  567.16      567.16  558.710    558.710
# 869  2014-03-31  556.97      556.97  566.890    566.890
# 870  2014-03-28  559.99      559.99  561.200    561.200
# 871  2014-03-27  558.46      558.46  568.000    568.000
#
# [872 rows x 5 columns]

# %%
from datetime import datetime
dates = np.array(data['Date'], dtype=np.datetime64)
x = list(dates)
y = [x.astype(float) for x in list(data['Open'])]

# %%
from bokeh.plotting import figure, output_file, show

p=figure(title='test', x_axis_label='Date', y_axis_label='Price',x_axis_type="datetime")
p.line(x,y)
show(p)

# %%
# Out:
# [numpy.datetime64('2017-09-11'),
#  numpy.datetime64('2017-09-08'),
#  numpy.datetime64('2017-09-07'),
#  numpy.datetime64('2017-09-06'),
#  numpy.datetime64('2017-09-05'),
#  numpy.datetime64('2017-09-01'),
#  numpy.datetime64('2017-08-31'),
#  numpy.datetime64('2017-08-30'),
#  numpy.datetime64('2017-08-29'),
#  numpy.datetime64('2017-08-28'),
#  numpy.datetime64('2017-08-25'),
#  numpy.datetime64('2017-08-24'),
#  numpy.datetime64('2017-08-23'),
#  numpy.datetime64('2017-08-22'),
#  numpy.datetime64('2017-08-21'),
#  numpy.datetime64('2017-08-18'),
#  numpy.datetime64('2017-08-17'),
#  numpy.datetime64('2017-08-16'),
#  numpy.datetime64('2017-08-15'),
#  numpy.datetime64('2017-08-14'),
#  numpy.datetime64('2017-08-11'),
#  numpy.datetime64('2017-08-10'),
#  numpy.datetime64('2017-08-09'),
#  numpy.datetime64('2017-08-08'),
#  numpy.datetime64('2017-08-07'),
#  numpy.datetime64('2017-08-04'),
#  numpy.datetime64('2017-08-03'),
#  numpy.datetime64('2017-08-02'),
#  numpy.datetime64('2017-08-01'),
#  numpy.datetime64('2017-07-31'),
#  numpy.datetime64('2017-07-28'),
#  numpy.datetime64('2017-07-27'),
#  numpy.datetime64('2017-07-26'),
#  numpy.datetime64('2017-07-25'),
#  numpy.datetime64('2017-07-24'),
#  numpy.datetime64('2017-07-21'),
#  numpy.datetime64('2017-07-20'),
#  numpy.datetime64('2017-07-19'),
#  numpy.datetime64('2017-07-18'),
#  numpy.datetime64('2017-07-17'),
#  numpy.datetime64('2017-07-14'),
#  numpy.datetime64('2017-07-13'),
#  numpy.datetime64('2017-07-12'),
#  numpy.datetime64('2017-07-11'),
#  numpy.datetime64('2017-07-10'),
#  numpy.datetime64('2017-07-07'),
#  numpy.datetime64('2017-07-06'),
#  numpy.datetime64('2017-07-05'),
#  numpy.datetime64('2017-07-03'),
#  numpy.datetime64('2017-06-30'),
#  numpy.datetime64('2017-06-29'),
#  numpy.datetime64('2017-06-28'),
#  numpy.datetime64('2017-06-27'),
#  numpy.datetime64('2017-06-26'),
#  numpy.datetime64('2017-06-23'),
#  numpy.datetime64('2017-06-22'),
#  numpy.datetime64('2017-06-21'),
#  numpy.datetime64('2017-06-20'),
#  numpy.datetime64('2017-06-19'),
#  numpy.datetime64('2017-06-16'),
#  numpy.datetime64('2017-06-15'),
#  numpy.datetime64('2017-06-14'),
#  numpy.datetime64('2017-06-13'),
#  numpy.datetime64('2017-06-12'),
#  numpy.datetime64('2017-06-09'),
#  numpy.datetime64('2017-06-08'),
#  numpy.datetime64('2017-06-07'),
#  numpy.datetime64('2017-06-06'),
#  numpy.datetime64('2017-06-05'),
#  numpy.datetime64('2017-06-02'),
#  numpy.datetime64('2017-06-01'),
#  numpy.datetime64('2017-05-31'),
#  numpy.datetime64('2017-05-30'),
#  numpy.datetime64('2017-05-26'),
#  numpy.datetime64('2017-05-25'),
#  numpy.datetime64('2017-05-24'),
#  numpy.datetime64('2017-05-23'),
#  numpy.datetime64('2017-05-22'),
#  numpy.datetime64('2017-05-19'),
#  numpy.datetime64('2017-05-18'),
#  numpy.datetime64('2017-05-17'),
#  numpy.datetime64('2017-05-16'),
#  numpy.datetime64('2017-05-15'),
#  numpy.datetime64('2017-05-12'),
#  numpy.datetime64('2017-05-11'),
#  numpy.datetime64('2017-05-10'),
#  numpy.datetime64('2017-05-09'),
#  numpy.datetime64('2017-05-08'),
#  numpy.datetime64('2017-05-05'),
#  numpy.datetime64('2017-05-04'),
#  numpy.datetime64('2017-05-03'),
#  numpy.datetime64('2017-05-02'),
#  numpy.datetime64('2017-05-01'),
#  numpy.datetime64('2017-04-28'),
#  numpy.datetime64('2017-04-27'),
#  numpy.datetime64('2017-04-26'),
#  numpy.datetime64('2017-04-25'),
#  numpy.datetime64('2017-04-24'),
#  numpy.datetime64('2017-04-21'),
#  numpy.datetime64('2017-04-20'),
#  numpy.datetime64('2017-04-19'),
#  numpy.datetime64('2017-04-18'),
#  numpy.datetime64('2017-04-17'),
#  numpy.datetime64('2017-04-13'),
#  numpy.datetime64('2017-04-12'),
#  numpy.datetime64('2017-04-11'),
#  numpy.datetime64('2017-04-10'),
#  numpy.datetime64('2017-04-07'),
#  numpy.datetime64('2017-04-06'),
#  numpy.datetime64('2017-04-05'),
#  numpy.datetime64('2017-04-04'),
#  numpy.datetime64('2017-04-03'),
#  numpy.datetime64('2017-03-31'),
#  numpy.datetime64('2017-03-30'),
#  numpy.datetime64('2017-03-29'),
#  numpy.datetime64('2017-03-28'),
#  numpy.datetime64('2017-03-27'),
#  numpy.datetime64('2017-03-24'),
#  numpy.datetime64('2017-03-23'),
#  numpy.datetime64('2017-03-22'),
#  numpy.datetime64('2017-03-21'),
#  numpy.datetime64('2017-03-20'),
#  numpy.datetime64('2017-03-17'),
#  numpy.datetime64('2017-03-16'),
#  numpy.datetime64('2017-03-15'),
#  numpy.datetime64('2017-03-14'),
#  numpy.datetime64('2017-03-13'),
#  numpy.datetime64('2017-03-10'),
#  numpy.datetime64('2017-03-09'),
#  numpy.datetime64('2017-03-08'),
#  numpy.datetime64('2017-03-07'),
#  numpy.datetime64('2017-03-06'),
#  numpy.datetime64('2017-03-03'),
#  numpy.datetime64('2017-03-02'),
#  numpy.datetime64('2017-03-01'),
#  numpy.datetime64('2017-02-28'),
#  numpy.datetime64('2017-02-27'),
#  numpy.datetime64('2017-02-24'),
#  numpy.datetime64('2017-02-23'),
#  numpy.datetime64('2017-02-22'),
#  numpy.datetime64('2017-02-21'),
#  numpy.datetime64('2017-02-17'),
#  numpy.datetime64('2017-02-16'),
#  numpy.datetime64('2017-02-15'),
#  numpy.datetime64('2017-02-14'),
#  numpy.datetime64('2017-02-13'),
#  numpy.datetime64('2017-02-10'),
#  numpy.datetime64('2017-02-09'),
#  numpy.datetime64('2017-02-08'),
#  numpy.datetime64('2017-02-07'),
#  numpy.datetime64('2017-02-06'),
#  numpy.datetime64('2017-02-03'),
#  numpy.datetime64('2017-02-02'),
#  numpy.datetime64('2017-02-01'),
#  numpy.datetime64('2017-01-31'),
#  numpy.datetime64('2017-01-30'),
#  numpy.datetime64('2017-01-27'),
#  numpy.datetime64('2017-01-26'),
#  numpy.datetime64('2017-01-25'),
#  numpy.datetime64('2017-01-24'),
#  numpy.datetime64('2017-01-23'),
#  numpy.datetime64('2017-01-20'),
#  numpy.datetime64('2017-01-19'),
#  numpy.datetime64('2017-01-18'),
#  numpy.datetime64('2017-01-17'),
#  numpy.datetime64('2017-01-13'),
#  numpy.datetime64('2017-01-12'),
#  numpy.datetime64('2017-01-11'),
#  numpy.datetime64('2017-01-10'),
#  numpy.datetime64('2017-01-09'),
#  numpy.datetime64('2017-01-06'),
#  numpy.datetime64('2017-01-05'),
#  numpy.datetime64('2017-01-04'),
#  numpy.datetime64('2017-01-03'),
#  numpy.datetime64('2016-12-30'),
#  numpy.datetime64('2016-12-29'),
#  numpy.datetime64('2016-12-28'),
#  numpy.datetime64('2016-12-27'),
#  numpy.datetime64('2016-12-23'),
#  numpy.datetime64('2016-12-22'),
#  numpy.datetime64('2016-12-21'),
#  numpy.datetime64('2016-12-20'),
#  numpy.datetime64('2016-12-19'),
#  numpy.datetime64('2016-12-16'),
#  numpy.datetime64('2016-12-15'),
#  numpy.datetime64('2016-12-14'),
#  numpy.datetime64('2016-12-13'),
#  numpy.datetime64('2016-12-12'),
#  numpy.datetime64('2016-12-09'),
#  numpy.datetime64('2016-12-08'),
#  numpy.datetime64('2016-12-07'),
#  numpy.datetime64('2016-12-06'),
#  numpy.datetime64('2016-12-05'),
#  numpy.datetime64('2016-12-02'),
#  numpy.datetime64('2016-12-01'),
#  numpy.datetime64('2016-11-30'),
#  numpy.datetime64('2016-11-29'),
#  numpy.datetime64('2016-11-28'),
#  numpy.datetime64('2016-11-25'),
#  numpy.datetime64('2016-11-23'),
#  numpy.datetime64('2016-11-22'),
#  numpy.datetime64('2016-11-21'),
#  numpy.datetime64('2016-11-18'),
#  numpy.datetime64('2016-11-17'),
#  numpy.datetime64('2016-11-16'),
#  numpy.datetime64('2016-11-15'),
#  numpy.datetime64('2016-11-14'),
#  numpy.datetime64('2016-11-11'),
#  numpy.datetime64('2016-11-10'),
#  numpy.datetime64('2016-11-09'),
#  numpy.datetime64('2016-11-08'),
#  numpy.datetime64('2016-11-07'),
#  numpy.datetime64('2016-11-04'),
#  numpy.datetime64('2016-11-03'),
#  numpy.datetime64('2016-11-02'),
#  numpy.datetime64('2016-11-01'),
#  numpy.datetime64('2016-10-31'),
#  numpy.datetime64('2016-10-28'),
#  numpy.datetime64('2016-10-27'),
#  numpy.datetime64('2016-10-26'),
#  numpy.datetime64('2016-10-25'),
#  numpy.datetime64('2016-10-24'),
#  numpy.datetime64('2016-10-21'),
#  numpy.datetime64('2016-10-20'),
#  numpy.datetime64('2016-10-19'),
#  numpy.datetime64('2016-10-18'),
#  numpy.datetime64('2016-10-17'),
#  numpy.datetime64('2016-10-14'),
#  numpy.datetime64('2016-10-13'),
#  numpy.datetime64('2016-10-12'),
#  numpy.datetime64('2016-10-11'),
#  numpy.datetime64('2016-10-10'),
#  numpy.datetime64('2016-10-07'),
#  numpy.datetime64('2016-10-06'),
#  numpy.datetime64('2016-10-05'),
#  numpy.datetime64('2016-10-04'),
#  numpy.datetime64('2016-10-03'),
#  numpy.datetime64('2016-09-30'),
#  numpy.datetime64('2016-09-29'),
#  numpy.datetime64('2016-09-28'),
#  numpy.datetime64('2016-09-27'),
#  numpy.datetime64('2016-09-26'),
#  numpy.datetime64('2016-09-23'),
#  numpy.datetime64('2016-09-22'),
#  numpy.datetime64('2016-09-21'),
#  numpy.datetime64('2016-09-20'),
#  numpy.datetime64('2016-09-19'),
#  numpy.datetime64('2016-09-16'),
#  numpy.datetime64('2016-09-15'),
#  numpy.datetime64('2016-09-14'),
#  numpy.datetime64('2016-09-13'),
#  numpy.datetime64('2016-09-12'),
#  numpy.datetime64('2016-09-09'),
#  numpy.datetime64('2016-09-08'),
#  numpy.datetime64('2016-09-07'),
#  numpy.datetime64('2016-09-06'),
#  numpy.datetime64('2016-09-02'),
#  numpy.datetime64('2016-09-01'),
#  numpy.datetime64('2016-08-31'),
#  numpy.datetime64('2016-08-30'),
#  numpy.datetime64('2016-08-29'),
#  numpy.datetime64('2016-08-26'),
#  numpy.datetime64('2016-08-25'),
#  numpy.datetime64('2016-08-24'),
#  numpy.datetime64('2016-08-23'),
#  numpy.datetime64('2016-08-22'),
#  numpy.datetime64('2016-08-19'),
#  numpy.datetime64('2016-08-18'),
#  numpy.datetime64('2016-08-17'),
#  numpy.datetime64('2016-08-16'),
#  numpy.datetime64('2016-08-15'),
#  numpy.datetime64('2016-08-12'),
#  numpy.datetime64('2016-08-11'),
#  numpy.datetime64('2016-08-10'),
#  numpy.datetime64('2016-08-09'),
#  numpy.datetime64('2016-08-08'),
#  numpy.datetime64('2016-08-05'),
#  numpy.datetime64('2016-08-04'),
#  numpy.datetime64('2016-08-03'),
#  numpy.datetime64('2016-08-02'),
#  numpy.datetime64('2016-08-01'),
#  numpy.datetime64('2016-07-29'),
#  numpy.datetime64('2016-07-28'),
#  numpy.datetime64('2016-07-27'),
#  numpy.datetime64('2016-07-26'),
#  numpy.datetime64('2016-07-25'),
#  numpy.datetime64('2016-07-22'),
#  numpy.datetime64('2016-07-21'),
#  numpy.datetime64('2016-07-20'),
#  numpy.datetime64('2016-07-19'),
#  numpy.datetime64('2016-07-18'),
#  numpy.datetime64('2016-07-15'),
#  numpy.datetime64('2016-07-14'),
#  numpy.datetime64('2016-07-13'),
#  numpy.datetime64('2016-07-12'),
#  numpy.datetime64('2016-07-11'),
#  numpy.datetime64('2016-07-08'),
#  numpy.datetime64('2016-07-07'),
#  numpy.datetime64('2016-07-06'),
#  numpy.datetime64('2016-07-05'),
#  numpy.datetime64('2016-07-01'),
#  numpy.datetime64('2016-06-30'),
#  numpy.datetime64('2016-06-29'),
#  numpy.datetime64('2016-06-28'),
#  numpy.datetime64('2016-06-27'),
#  numpy.datetime64('2016-06-24'),
#  numpy.datetime64('2016-06-23'),
#  numpy.datetime64('2016-06-22'),
#  numpy.datetime64('2016-06-21'),
#  numpy.datetime64('2016-06-20'),
#  numpy.datetime64('2016-06-17'),
#  numpy.datetime64('2016-06-16'),
#  numpy.datetime64('2016-06-15'),
#  numpy.datetime64('2016-06-14'),
#  numpy.datetime64('2016-06-13'),
#  numpy.datetime64('2016-06-10'),
#  numpy.datetime64('2016-06-09'),
#  numpy.datetime64('2016-06-08'),
#  numpy.datetime64('2016-06-07'),
#  numpy.datetime64('2016-06-06'),
#  numpy.datetime64('2016-06-03'),
#  numpy.datetime64('2016-06-02'),
#  numpy.datetime64('2016-06-01'),
#  numpy.datetime64('2016-05-31'),
#  numpy.datetime64('2016-05-27'),
#  numpy.datetime64('2016-05-26'),
#  numpy.datetime64('2016-05-25'),
#  numpy.datetime64('2016-05-24'),
#  numpy.datetime64('2016-05-23'),
#  numpy.datetime64('2016-05-20'),
#  numpy.datetime64('2016-05-19'),
#  numpy.datetime64('2016-05-18'),
#  numpy.datetime64('2016-05-17'),
#  numpy.datetime64('2016-05-16'),
#  numpy.datetime64('2016-05-13'),
#  numpy.datetime64('2016-05-12'),
#  numpy.datetime64('2016-05-11'),
#  numpy.datetime64('2016-05-10'),
#  numpy.datetime64('2016-05-09'),
#  numpy.datetime64('2016-05-06'),
#  numpy.datetime64('2016-05-05'),
#  numpy.datetime64('2016-05-04'),
#  numpy.datetime64('2016-05-03'),
#  numpy.datetime64('2016-05-02'),
#  numpy.datetime64('2016-04-29'),
#  numpy.datetime64('2016-04-28'),
#  numpy.datetime64('2016-04-27'),
#  numpy.datetime64('2016-04-26'),
#  numpy.datetime64('2016-04-25'),
#  numpy.datetime64('2016-04-22'),
#  numpy.datetime64('2016-04-21'),
#  numpy.datetime64('2016-04-20'),
#  numpy.datetime64('2016-04-19'),
#  numpy.datetime64('2016-04-18'),
#  numpy.datetime64('2016-04-15'),
#  numpy.datetime64('2016-04-14'),
#  numpy.datetime64('2016-04-13'),
#  numpy.datetime64('2016-04-12'),
#  numpy.datetime64('2016-04-11'),
#  numpy.datetime64('2016-04-08'),
#  numpy.datetime64('2016-04-07'),
#  numpy.datetime64('2016-04-06'),
#  numpy.datetime64('2016-04-05'),
#  numpy.datetime64('2016-04-04'),
#  numpy.datetime64('2016-04-01'),
#  numpy.datetime64('2016-03-31'),
#  numpy.datetime64('2016-03-30'),
#  numpy.datetime64('2016-03-29'),
#  numpy.datetime64('2016-03-28'),
#  numpy.datetime64('2016-03-24'),
#  numpy.datetime64('2016-03-23'),
#  numpy.datetime64('2016-03-22'),
#  numpy.datetime64('2016-03-21'),
#  numpy.datetime64('2016-03-18'),
#  numpy.datetime64('2016-03-17'),
#  numpy.datetime64('2016-03-16'),
#  numpy.datetime64('2016-03-15'),
#  numpy.datetime64('2016-03-14'),
#  numpy.datetime64('2016-03-11'),
#  numpy.datetime64('2016-03-10'),
#  numpy.datetime64('2016-03-09'),
#  numpy.datetime64('2016-03-08'),
#  numpy.datetime64('2016-03-07'),
#  numpy.datetime64('2016-03-04'),
#  numpy.datetime64('2016-03-03'),
#  numpy.datetime64('2016-03-02'),
#  numpy.datetime64('2016-03-01'),
#  numpy.datetime64('2016-02-29'),
#  numpy.datetime64('2016-02-26'),
#  numpy.datetime64('2016-02-25'),
#  numpy.datetime64('2016-02-24'),
#  numpy.datetime64('2016-02-23'),
#  numpy.datetime64('2016-02-22'),
#  numpy.datetime64('2016-02-19'),
#  numpy.datetime64('2016-02-18'),
#  numpy.datetime64('2016-02-17'),
#  numpy.datetime64('2016-02-16'),
#  numpy.datetime64('2016-02-12'),
#  numpy.datetime64('2016-02-11'),
#  numpy.datetime64('2016-02-10'),
#  numpy.datetime64('2016-02-09'),
#  numpy.datetime64('2016-02-08'),
#  numpy.datetime64('2016-02-05'),
#  numpy.datetime64('2016-02-04'),
#  numpy.datetime64('2016-02-03'),
#  numpy.datetime64('2016-02-02'),
#  numpy.datetime64('2016-02-01'),
#  numpy.datetime64('2016-01-29'),
#  numpy.datetime64('2016-01-28'),
#  numpy.datetime64('2016-01-27'),
#  numpy.datetime64('2016-01-26'),
#  numpy.datetime64('2016-01-25'),
#  numpy.datetime64('2016-01-22'),
#  numpy.datetime64('2016-01-21'),
#  numpy.datetime64('2016-01-20'),
#  numpy.datetime64('2016-01-19'),
#  numpy.datetime64('2016-01-15'),
#  numpy.datetime64('2016-01-14'),
#  numpy.datetime64('2016-01-13'),
#  numpy.datetime64('2016-01-12'),
#  numpy.datetime64('2016-01-11'),
#  numpy.datetime64('2016-01-08'),
#  numpy.datetime64('2016-01-07'),
#  numpy.datetime64('2016-01-06'),
#  numpy.datetime64('2016-01-05'),
#  numpy.datetime64('2016-01-04'),
#  numpy.datetime64('2015-12-31'),
#  numpy.datetime64('2015-12-30'),
#  numpy.datetime64('2015-12-29'),
#  numpy.datetime64('2015-12-28'),
#  numpy.datetime64('2015-12-24'),
#  numpy.datetime64('2015-12-23'),
#  numpy.datetime64('2015-12-22'),
#  numpy.datetime64('2015-12-21'),
#  numpy.datetime64('2015-12-18'),
#  numpy.datetime64('2015-12-17'),
#  numpy.datetime64('2015-12-16'),
#  numpy.datetime64('2015-12-15'),
#  numpy.datetime64('2015-12-14'),
#  numpy.datetime64('2015-12-11'),
#  numpy.datetime64('2015-12-10'),
#  numpy.datetime64('2015-12-09'),
#  numpy.datetime64('2015-12-08'),
#  numpy.datetime64('2015-12-07'),
#  numpy.datetime64('2015-12-04'),
#  numpy.datetime64('2015-12-03'),
#  numpy.datetime64('2015-12-02'),
#  numpy.datetime64('2015-12-01'),
#  numpy.datetime64('2015-11-30'),
#  numpy.datetime64('2015-11-27'),
#  numpy.datetime64('2015-11-25'),
#  numpy.datetime64('2015-11-24'),
#  numpy.datetime64('2015-11-23'),
#  numpy.datetime64('2015-11-20'),
#  numpy.datetime64('2015-11-19'),
#  numpy.datetime64('2015-11-18'),
#  numpy.datetime64('2015-11-17'),
#  numpy.datetime64('2015-11-16'),
#  numpy.datetime64('2015-11-13'),
#  numpy.datetime64('2015-11-12'),
#  numpy.datetime64('2015-11-11'),
#  numpy.datetime64('2015-11-10'),
#  numpy.datetime64('2015-11-09'),
#  numpy.datetime64('2015-11-06'),
#  numpy.datetime64('2015-11-05'),
#  numpy.datetime64('2015-11-04'),
#  numpy.datetime64('2015-11-03'),
#  numpy.datetime64('2015-11-02'),
#  numpy.datetime64('2015-10-30'),
#  numpy.datetime64('2015-10-29'),
#  numpy.datetime64('2015-10-28'),
#  numpy.datetime64('2015-10-27'),
#  numpy.datetime64('2015-10-26'),
#  numpy.datetime64('2015-10-23'),
#  numpy.datetime64('2015-10-22'),
#  numpy.datetime64('2015-10-21'),
#  numpy.datetime64('2015-10-20'),
#  numpy.datetime64('2015-10-19'),
#  numpy.datetime64('2015-10-16'),
#  numpy.datetime64('2015-10-15'),
#  numpy.datetime64('2015-10-14'),
#  numpy.datetime64('2015-10-13'),
#  numpy.datetime64('2015-10-12'),
#  numpy.datetime64('2015-10-09'),
#  numpy.datetime64('2015-10-08'),
#  numpy.datetime64('2015-10-07'),
#  numpy.datetime64('2015-10-06'),
#  numpy.datetime64('2015-10-05'),
#  numpy.datetime64('2015-10-02'),
#  numpy.datetime64('2015-10-01'),
#  numpy.datetime64('2015-09-30'),
#  numpy.datetime64('2015-09-29'),
#  numpy.datetime64('2015-09-28'),
#  numpy.datetime64('2015-09-25'),
#  numpy.datetime64('2015-09-24'),
#  numpy.datetime64('2015-09-23'),
#  numpy.datetime64('2015-09-22'),
#  numpy.datetime64('2015-09-21'),
#  numpy.datetime64('2015-09-18'),
#  numpy.datetime64('2015-09-17'),
#  numpy.datetime64('2015-09-16'),
#  numpy.datetime64('2015-09-15'),
#  numpy.datetime64('2015-09-14'),
#  numpy.datetime64('2015-09-11'),
#  numpy.datetime64('2015-09-10'),
#  numpy.datetime64('2015-09-09'),
#  numpy.datetime64('2015-09-08'),
#  numpy.datetime64('2015-09-04'),
#  numpy.datetime64('2015-09-03'),
#  numpy.datetime64('2015-09-02'),
#  numpy.datetime64('2015-09-01'),
#  numpy.datetime64('2015-08-31'),
#  numpy.datetime64('2015-08-28'),
#  numpy.datetime64('2015-08-27'),
#  numpy.datetime64('2015-08-26'),
#  numpy.datetime64('2015-08-25'),
#  numpy.datetime64('2015-08-24'),
#  numpy.datetime64('2015-08-21'),
#  numpy.datetime64('2015-08-20'),
#  numpy.datetime64('2015-08-19'),
#  numpy.datetime64('2015-08-18'),
#  numpy.datetime64('2015-08-17'),
#  numpy.datetime64('2015-08-14'),
#  numpy.datetime64('2015-08-13'),
#  numpy.datetime64('2015-08-12'),
#  numpy.datetime64('2015-08-11'),
#  numpy.datetime64('2015-08-10'),
#  numpy.datetime64('2015-08-07'),
#  numpy.datetime64('2015-08-06'),
#  numpy.datetime64('2015-08-05'),
#  numpy.datetime64('2015-08-04'),
#  numpy.datetime64('2015-08-03'),
#  numpy.datetime64('2015-07-31'),
#  numpy.datetime64('2015-07-30'),
#  numpy.datetime64('2015-07-29'),
#  numpy.datetime64('2015-07-28'),
#  numpy.datetime64('2015-07-27'),
#  numpy.datetime64('2015-07-24'),
#  numpy.datetime64('2015-07-23'),
#  numpy.datetime64('2015-07-22'),
#  numpy.datetime64('2015-07-21'),
#  numpy.datetime64('2015-07-20'),
#  numpy.datetime64('2015-07-17'),
#  numpy.datetime64('2015-07-16'),
#  numpy.datetime64('2015-07-15'),
#  numpy.datetime64('2015-07-14'),
#  numpy.datetime64('2015-07-13'),
#  numpy.datetime64('2015-07-10'),
#  numpy.datetime64('2015-07-09'),
#  numpy.datetime64('2015-07-08'),
#  numpy.datetime64('2015-07-07'),
#  numpy.datetime64('2015-07-06'),
#  numpy.datetime64('2015-07-02'),
#  numpy.datetime64('2015-07-01'),
#  numpy.datetime64('2015-06-30'),
#  numpy.datetime64('2015-06-29'),
#  numpy.datetime64('2015-06-26'),
#  numpy.datetime64('2015-06-25'),
#  numpy.datetime64('2015-06-24'),
#  numpy.datetime64('2015-06-23'),
#  numpy.datetime64('2015-06-22'),
#  numpy.datetime64('2015-06-19'),
#  numpy.datetime64('2015-06-18'),
#  numpy.datetime64('2015-06-17'),
#  numpy.datetime64('2015-06-16'),
#  numpy.datetime64('2015-06-15'),
#  numpy.datetime64('2015-06-12'),
#  numpy.datetime64('2015-06-11'),
#  numpy.datetime64('2015-06-10'),
#  numpy.datetime64('2015-06-09'),
#  numpy.datetime64('2015-06-08'),
#  numpy.datetime64('2015-06-05'),
#  numpy.datetime64('2015-06-04'),
#  numpy.datetime64('2015-06-03'),
#  numpy.datetime64('2015-06-02'),
#  numpy.datetime64('2015-06-01'),
#  numpy.datetime64('2015-05-29'),
#  numpy.datetime64('2015-05-28'),
#  numpy.datetime64('2015-05-27'),
#  numpy.datetime64('2015-05-26'),
#  numpy.datetime64('2015-05-22'),
#  numpy.datetime64('2015-05-21'),
#  numpy.datetime64('2015-05-20'),
#  numpy.datetime64('2015-05-19'),
#  numpy.datetime64('2015-05-18'),
#  numpy.datetime64('2015-05-15'),
#  numpy.datetime64('2015-05-14'),
#  numpy.datetime64('2015-05-13'),
#  numpy.datetime64('2015-05-12'),
#  numpy.datetime64('2015-05-11'),
#  numpy.datetime64('2015-05-08'),
#  numpy.datetime64('2015-05-07'),
#  numpy.datetime64('2015-05-06'),
#  numpy.datetime64('2015-05-05'),
#  numpy.datetime64('2015-05-04'),
#  numpy.datetime64('2015-05-01'),
#  numpy.datetime64('2015-04-30'),
#  numpy.datetime64('2015-04-29'),
#  numpy.datetime64('2015-04-28'),
#  numpy.datetime64('2015-04-27'),
#  numpy.datetime64('2015-04-24'),
#  numpy.datetime64('2015-04-23'),
#  numpy.datetime64('2015-04-22'),
#  numpy.datetime64('2015-04-21'),
#  numpy.datetime64('2015-04-20'),
#  numpy.datetime64('2015-04-17'),
#  numpy.datetime64('2015-04-16'),
#  numpy.datetime64('2015-04-15'),
#  numpy.datetime64('2015-04-14'),
#  numpy.datetime64('2015-04-13'),
#  numpy.datetime64('2015-04-10'),
#  numpy.datetime64('2015-04-09'),
#  numpy.datetime64('2015-04-08'),
#  numpy.datetime64('2015-04-07'),
#  numpy.datetime64('2015-04-06'),
#  numpy.datetime64('2015-04-02'),
#  numpy.datetime64('2015-04-01'),
#  numpy.datetime64('2015-03-31'),
#  numpy.datetime64('2015-03-30'),
#  numpy.datetime64('2015-03-27'),
#  numpy.datetime64('2015-03-26'),
#  numpy.datetime64('2015-03-25'),
#  numpy.datetime64('2015-03-24'),
#  numpy.datetime64('2015-03-23'),
#  numpy.datetime64('2015-03-20'),
#  numpy.datetime64('2015-03-19'),
#  numpy.datetime64('2015-03-18'),
#  numpy.datetime64('2015-03-17'),
#  numpy.datetime64('2015-03-16'),
#  numpy.datetime64('2015-03-13'),
#  numpy.datetime64('2015-03-12'),
#  numpy.datetime64('2015-03-11'),
#  numpy.datetime64('2015-03-10'),
#  numpy.datetime64('2015-03-09'),
#  numpy.datetime64('2015-03-06'),
#  numpy.datetime64('2015-03-05'),
#  numpy.datetime64('2015-03-04'),
#  numpy.datetime64('2015-03-03'),
#  numpy.datetime64('2015-03-02'),
#  numpy.datetime64('2015-02-27'),
#  numpy.datetime64('2015-02-26'),
#  numpy.datetime64('2015-02-25'),
#  numpy.datetime64('2015-02-24'),
#  numpy.datetime64('2015-02-23'),
#  numpy.datetime64('2015-02-20'),
#  numpy.datetime64('2015-02-19'),
#  numpy.datetime64('2015-02-18'),
#  numpy.datetime64('2015-02-17'),
#  numpy.datetime64('2015-02-13'),
#  numpy.datetime64('2015-02-12'),
#  numpy.datetime64('2015-02-11'),
#  numpy.datetime64('2015-02-10'),
#  numpy.datetime64('2015-02-09'),
#  numpy.datetime64('2015-02-06'),
#  numpy.datetime64('2015-02-05'),
#  numpy.datetime64('2015-02-04'),
#  numpy.datetime64('2015-02-03'),
#  numpy.datetime64('2015-02-02'),
#  numpy.datetime64('2015-01-30'),
#  numpy.datetime64('2015-01-29'),
#  numpy.datetime64('2015-01-28'),
#  numpy.datetime64('2015-01-27'),
#  numpy.datetime64('2015-01-26'),
#  numpy.datetime64('2015-01-23'),
#  numpy.datetime64('2015-01-22'),
#  numpy.datetime64('2015-01-21'),
#  numpy.datetime64('2015-01-20'),
#  numpy.datetime64('2015-01-16'),
#  numpy.datetime64('2015-01-15'),
#  numpy.datetime64('2015-01-14'),
#  numpy.datetime64('2015-01-13'),
#  numpy.datetime64('2015-01-12'),
#  numpy.datetime64('2015-01-09'),
#  numpy.datetime64('2015-01-08'),
#  numpy.datetime64('2015-01-07'),
#  numpy.datetime64('2015-01-06'),
#  numpy.datetime64('2015-01-05'),
#  numpy.datetime64('2015-01-02'),
#  numpy.datetime64('2014-12-31'),
#  numpy.datetime64('2014-12-30'),
#  numpy.datetime64('2014-12-29'),
#  numpy.datetime64('2014-12-26'),
#  numpy.datetime64('2014-12-24'),
#  numpy.datetime64('2014-12-23'),
#  numpy.datetime64('2014-12-22'),
#  numpy.datetime64('2014-12-19'),
#  numpy.datetime64('2014-12-18'),
#  numpy.datetime64('2014-12-17'),
#  numpy.datetime64('2014-12-16'),
#  numpy.datetime64('2014-12-15'),
#  numpy.datetime64('2014-12-12'),
#  numpy.datetime64('2014-12-11'),
#  numpy.datetime64('2014-12-10'),
#  numpy.datetime64('2014-12-09'),
#  numpy.datetime64('2014-12-08'),
#  numpy.datetime64('2014-12-05'),
#  numpy.datetime64('2014-12-04'),
#  numpy.datetime64('2014-12-03'),
#  numpy.datetime64('2014-12-02'),
#  numpy.datetime64('2014-12-01'),
#  numpy.datetime64('2014-11-28'),
#  numpy.datetime64('2014-11-26'),
#  numpy.datetime64('2014-11-25'),
#  numpy.datetime64('2014-11-24'),
#  numpy.datetime64('2014-11-21'),
#  numpy.datetime64('2014-11-20'),
#  numpy.datetime64('2014-11-19'),
#  numpy.datetime64('2014-11-18'),
#  numpy.datetime64('2014-11-17'),
#  numpy.datetime64('2014-11-14'),
#  numpy.datetime64('2014-11-13'),
#  numpy.datetime64('2014-11-12'),
#  numpy.datetime64('2014-11-11'),
#  numpy.datetime64('2014-11-10'),
#  numpy.datetime64('2014-11-07'),
#  numpy.datetime64('2014-11-06'),
#  numpy.datetime64('2014-11-05'),
#  numpy.datetime64('2014-11-04'),
#  numpy.datetime64('2014-11-03'),
#  numpy.datetime64('2014-10-31'),
#  numpy.datetime64('2014-10-30'),
#  numpy.datetime64('2014-10-29'),
#  numpy.datetime64('2014-10-28'),
#  numpy.datetime64('2014-10-27'),
#  numpy.datetime64('2014-10-24'),
#  numpy.datetime64('2014-10-23'),
#  numpy.datetime64('2014-10-22'),
#  numpy.datetime64('2014-10-21'),
#  numpy.datetime64('2014-10-20'),
#  numpy.datetime64('2014-10-17'),
#  numpy.datetime64('2014-10-16'),
#  numpy.datetime64('2014-10-15'),
#  numpy.datetime64('2014-10-14'),
#  numpy.datetime64('2014-10-13'),
#  numpy.datetime64('2014-10-10'),
#  numpy.datetime64('2014-10-09'),
#  numpy.datetime64('2014-10-08'),
#  numpy.datetime64('2014-10-07'),
#  numpy.datetime64('2014-10-06'),
#  numpy.datetime64('2014-10-03'),
#  numpy.datetime64('2014-10-02'),
#  numpy.datetime64('2014-10-01'),
#  numpy.datetime64('2014-09-30'),
#  numpy.datetime64('2014-09-29'),
#  numpy.datetime64('2014-09-26'),
#  numpy.datetime64('2014-09-25'),
#  numpy.datetime64('2014-09-24'),
#  numpy.datetime64('2014-09-23'),
#  numpy.datetime64('2014-09-22'),
#  numpy.datetime64('2014-09-19'),
#  numpy.datetime64('2014-09-18'),
#  numpy.datetime64('2014-09-17'),
#  numpy.datetime64('2014-09-16'),
#  numpy.datetime64('2014-09-15'),
#  numpy.datetime64('2014-09-12'),
#  numpy.datetime64('2014-09-11'),
#  numpy.datetime64('2014-09-10'),
#  numpy.datetime64('2014-09-09'),
#  numpy.datetime64('2014-09-08'),
#  numpy.datetime64('2014-09-05'),
#  numpy.datetime64('2014-09-04'),
#  numpy.datetime64('2014-09-03'),
#  numpy.datetime64('2014-09-02'),
#  numpy.datetime64('2014-08-29'),
#  numpy.datetime64('2014-08-28'),
#  numpy.datetime64('2014-08-27'),
#  numpy.datetime64('2014-08-26'),
#  numpy.datetime64('2014-08-25'),
#  numpy.datetime64('2014-08-22'),
#  numpy.datetime64('2014-08-21'),
#  numpy.datetime64('2014-08-20'),
#  numpy.datetime64('2014-08-19'),
#  numpy.datetime64('2014-08-18'),
#  numpy.datetime64('2014-08-15'),
#  numpy.datetime64('2014-08-14'),
#  numpy.datetime64('2014-08-13'),
#  numpy.datetime64('2014-08-12'),
#  numpy.datetime64('2014-08-11'),
#  numpy.datetime64('2014-08-08'),
#  numpy.datetime64('2014-08-07'),
#  numpy.datetime64('2014-08-06'),
#  numpy.datetime64('2014-08-05'),
#  numpy.datetime64('2014-08-04'),
#  numpy.datetime64('2014-08-01'),
#  numpy.datetime64('2014-07-31'),
#  numpy.datetime64('2014-07-30'),
#  numpy.datetime64('2014-07-29'),
#  numpy.datetime64('2014-07-28'),
#  numpy.datetime64('2014-07-25'),
#  numpy.datetime64('2014-07-24'),
#  numpy.datetime64('2014-07-23'),
#  numpy.datetime64('2014-07-22'),
#  numpy.datetime64('2014-07-21'),
#  numpy.datetime64('2014-07-18'),
#  numpy.datetime64('2014-07-17'),
#  numpy.datetime64('2014-07-16'),
#  numpy.datetime64('2014-07-15'),
#  numpy.datetime64('2014-07-14'),
#  numpy.datetime64('2014-07-11'),
#  numpy.datetime64('2014-07-10'),
#  numpy.datetime64('2014-07-09'),
#  numpy.datetime64('2014-07-08'),
#  numpy.datetime64('2014-07-07'),
#  numpy.datetime64('2014-07-03'),
#  numpy.datetime64('2014-07-02'),
#  numpy.datetime64('2014-07-01'),
#  numpy.datetime64('2014-06-30'),
#  numpy.datetime64('2014-06-27'),
#  numpy.datetime64('2014-06-26'),
#  numpy.datetime64('2014-06-25'),
#  numpy.datetime64('2014-06-24'),
#  numpy.datetime64('2014-06-23'),
#  numpy.datetime64('2014-06-20'),
#  numpy.datetime64('2014-06-19'),
#  numpy.datetime64('2014-06-18'),
#  numpy.datetime64('2014-06-17'),
#  numpy.datetime64('2014-06-16'),
#  numpy.datetime64('2014-06-13'),
#  numpy.datetime64('2014-06-12'),
#  numpy.datetime64('2014-06-11'),
#  numpy.datetime64('2014-06-10'),
#  numpy.datetime64('2014-06-09'),
#  numpy.datetime64('2014-06-06'),
#  numpy.datetime64('2014-06-05'),
#  numpy.datetime64('2014-06-04'),
#  numpy.datetime64('2014-06-03'),
#  numpy.datetime64('2014-06-02'),
#  numpy.datetime64('2014-05-30'),
#  numpy.datetime64('2014-05-29'),
#  numpy.datetime64('2014-05-28'),
#  numpy.datetime64('2014-05-27'),
#  numpy.datetime64('2014-05-23'),
#  numpy.datetime64('2014-05-22'),
#  numpy.datetime64('2014-05-21'),
#  numpy.datetime64('2014-05-20'),
#  numpy.datetime64('2014-05-19'),
#  numpy.datetime64('2014-05-16'),
#  numpy.datetime64('2014-05-15'),
#  numpy.datetime64('2014-05-14'),
#  numpy.datetime64('2014-05-13'),
#  numpy.datetime64('2014-05-12'),
#  numpy.datetime64('2014-05-09'),
#  numpy.datetime64('2014-05-08'),
#  numpy.datetime64('2014-05-07'),
#  numpy.datetime64('2014-05-06'),
#  numpy.datetime64('2014-05-05'),
#  numpy.datetime64('2014-05-02'),
#  numpy.datetime64('2014-05-01'),
#  numpy.datetime64('2014-04-30'),
#  numpy.datetime64('2014-04-29'),
#  numpy.datetime64('2014-04-28'),
#  numpy.datetime64('2014-04-25'),
#  numpy.datetime64('2014-04-24'),
#  numpy.datetime64('2014-04-23'),
#  numpy.datetime64('2014-04-22'),
#  numpy.datetime64('2014-04-21'),
#  numpy.datetime64('2014-04-17'),
#  numpy.datetime64('2014-04-16'),
#  numpy.datetime64('2014-04-15'),
#  numpy.datetime64('2014-04-14'),
#  numpy.datetime64('2014-04-11'),
#  numpy.datetime64('2014-04-10'),
#  numpy.datetime64('2014-04-09'),
#  numpy.datetime64('2014-04-08'),
#  numpy.datetime64('2014-04-07'),
#  numpy.datetime64('2014-04-04'),
#  numpy.datetime64('2014-04-03'),
#  numpy.datetime64('2014-04-02'),
#  numpy.datetime64('2014-04-01'),
#  numpy.datetime64('2014-03-31'),
#  numpy.datetime64('2014-03-28'),
#  numpy.datetime64('2014-03-27')]
